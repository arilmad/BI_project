# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Remove descriptions in first 5 rows and verify integrity

# %%
df = pd.read_csv('raw\\oil\\Europe_Brent_Spot_Price_FOB_Daily.csv', skiprows=5, parse_dates=True, index_col=0,
                names=['USD_per_barrel'], dtype='float32')
len(df)
# Out:
# 8370

# %%
df.head(5)
# Out:
#             USD_per_barrel
# 2020-04-28           15.60
# 2020-04-27           15.17
# 2020-04-24           15.87
# 2020-04-23           15.06
# 2020-04-22           13.77

# %%
fig, ax = plt.subplots(1,1,figsize=(20,10))
ax.plot(df['USD_per_barrel'])
plt.show()

# %%
df.to_csv('src\\oilspot_prices\\Brent_oilspot_prices.csv')
